# %%
import pandas as pd

# %%
df=pd.read_excel("./data/mobile_data.xlsx")

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
df.columns
# Out:
# Index(['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time',
#        'processor_frequency', 'thickness', 'flash_type',
#        'front_camera_resolution', 'auto_focus', 'screen_size',
#        'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os',
#        'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time',
#        'video_resolution', 'display_resolution', 'removable_battery',
#        'display_type', 'primary_camera_resolution', 'battery_type',
#        'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores',
#        'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate',
#        'phone_width', 'expandable_memory', 'version', 'usb_type',
#        'battery_capacity', 'processor_rank', 'is_liked'],
#       dtype='object')

# %%
df.shape
# Out:
# (109, 40)

# %% [markdown]
# ##### Indexing, Selecting and Slicing Data in Pandas
#
# Pandas now supports three types of Multi-axes indexing:
#
# **.loc()**\
# Pandas provide various methods to have purely label based indexing. When slicing, the start bound is also included. Integers are valid labels, but they refer to the label and not the position.
#
# **.iloc()**\
# Pandas provide various methods in order to get purely integer based indexing. Like python and numpy, these are 0-based indexing.
#
# **.ix()**-- Not available for some pandas version\
# Besides pure label based and integer based, Pandas provides a hybrid method for selections and subsetting the object using the .ix() operator.

# %%
df.loc[:,:]
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0            250                  1.3
# 1           0         1        55   132.0            300                  1.3
# 2           0         9        55   142.0            329                  1.5
# 3           0         8        55   152.0            385                  1.3
# 4           1         1        55   234.0            385                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
# ...

# %%
df.loc[:,'sim_type']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 104    3
# 105    0
# 106    3
# 107    3
# 108    2
# Name: sim_type, Length: 109, dtype: int64

# %%
df['sim_type']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 104    3
# 105    0
# 106    3
# 107    3
# 108    2
# Name: sim_type, Length: 109, dtype: int64

# %%
df.loc[:,['sim_type','aperture']]
# Out:
#      sim_type  aperture
# 0           0        12
# 1           0         1
# 2           0         9
# 3           0         8
# 4           1         1
# ..        ...       ...
# 104         3        10
# 105         0         5
# 106         3        10
# 107         3        10
# 108         2         8
#
# [109 rows x 2 columns]

# %%
df[['sim_type','aperture']]
# Out:
#      sim_type  aperture
# 0           0        12
# 1           0         1
# 2           0         9
# 3           0         8
# 4           1         1
# ..        ...       ...
# 104         3        10
# 105         0         5
# 106         3        10
# 107         3        10
# 108         2         8
#
# [109 rows x 2 columns]

# %%
# Numeric Indexing
df.iloc[:4]
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                      2.0           0  ...
# 1       10.6           5                      0.3           1  ...
# 2        8.5           5                      2.0           3  ...
# 3        8.0           5                      2.0           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0              4                     2                 3         67.8
# 1              4                     4                 6         64.0
# ...

# %%
df.iloc[:4,:2]
# Out:
#    sim_type  aperture
# 0         0        12
# 1         0         1
# 2         0         9
# 3         0         8

# %%
df['aperture'].aggregate(sum)
# Out:
# 843

# %%
df['aperture']>10
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# Name: aperture, Length: 109, dtype: bool

# %%
df[df['aperture']>10]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0          0        12        55   155.0            250                  1.3
# 5          0        14        55   179.0            280                  1.3
# 13         0        11        43   133.0            198                  1.2
# 47         0        13        34   138.0            761                  1.7
# 63         0        13        29   189.0            600                  1.5
# 96         3        12        16   149.0            410                  2.5
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0        10.5           5                      2.0           0  ...
# 5         7.9           5                      5.0           3  ...
# 13        9.0           5                      2.0           3  ...
# 47        8.2           5                      5.0           3  ...
# 63        9.9           2                      5.0           3  ...
# ...

# %%
df[df['aperture']==10]['gpu_rank']
# Out:
# 11     55
# 15     41
# 16     47
# 17     43
# 18     41
# 19     43
# 21     34
# 24     29
# 29     43
# 33     28
# 34     28
# 36     34
# 37     38
# 45     38
# 46     29
# 52     30
# 56     29
# 57     16
# 60     16
# 64     15
# 65     29
# 68     34
# 70     34
# 72     17
# 74     16
# 83     28
# 84     25
# 85     11
# 86     21
# 91      6
# 93     12
# 94     12
# 95     28
# 99     12
# 101     6
# 104    14
# 106     6
# 107    12
# Name: gpu_rank, dtype: int64

# %%
df.sort_values(['aperture'])
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 38         2         0        27   128.0            490                  1.7
# 54         0         1        44   154.5            560                  1.7
# 55         1         1        44   171.8           1093                  1.4
# 40         0         1        38   143.0            275                  1.3
# 28         0         1        44   160.0            617                  1.7
# ..       ...       ...       ...     ...            ...                  ...
# 96         3        12        16   149.0            410                  2.5
# 0          0        12        55   155.0            250                  1.3
# 63         0        13        29   189.0            600                  1.5
# 47         0        13        34   138.0            761                  1.7
# 5          0        14        55   179.0            280                  1.3
#
# ...

# %%
df.sort_values(['aperture'], ascending=False)
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 5          0        14        55   179.0            280                  1.3
# 63         0        13        29   189.0            600                  1.5
# 47         0        13        34   138.0            761                  1.7
# 0          0        12        55   155.0            250                  1.3
# 96         3        12        16   149.0            410                  2.5
# ..       ...       ...       ...     ...            ...                  ...
# 40         0         1        38   143.0            275                  1.3
# 1          0         1        55   132.0            300                  1.3
# 55         1         1        44   171.8           1093                  1.4
# 54         0         1        44   154.5            560                  1.7
# 38         2         0        27   128.0            490                  1.7
#
# ...

# %% [markdown]
# ##### Group By
# Pandas `dataframe.groupby()` function is used to split the data into groups based on some criteria. pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names.
#
# ![image.png](https://redash.io/assets/images/docs/gitbook/group-by-ex.png)

# %%
df['sim_type'].value_counts()
# Out:
# 0    65
# 3    25
# 1    12
# 2     4
# 4     3
# Name: sim_type, dtype: int64

# %%
df.groupby("sim_type").count()
# Out:
#           aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# sim_type
# 0               65        65      65             65                   65
# 1               12        12      12             12                   12
# 2                4         4       4              4                    4
# 3               25        25      25             25                   25
# 4                3         3       3              3                    3
#
#           thickness  flash_type  front_camera_resolution  auto_focus  \
# sim_type
# 0                65          65                       65          65
# 1                12          12                       12          12
# 2                 4           4                        4           4
# 3                25          25                       25          25
# 4                 3           3                        3           3
#
#           screen_size  ...  micro_sd_slot  screen_pixel_density  \
# ...

# %%
df.groupby("sim_type").mean()
# Out:
#           aperture   gpu_rank      weight  stand_by_time  processor_frequency  \
# sim_type
# 0         7.830769  36.015385  155.641538     396.661538             1.541538
# 1         7.083333  36.250000  164.033333     516.333333             1.483333
# 2         4.750000  21.000000  146.500000     521.000000             1.925000
# 3         8.320000  14.680000  147.360000     354.600000             1.877600
# 4         7.333333  14.000000  156.666667     393.333333             1.800000
#
#           thickness  flash_type  front_camera_resolution  auto_focus  \
# sim_type
# 0          8.592308    4.138462                 5.035385    2.938462
# 1          8.075000    4.083333                 4.751667    3.000000
# 2          8.175000    4.750000                 6.500000    3.000000
# 3          7.784000    3.160000                 3.972000    2.960000
# 4          8.433333    1.000000                 6.000000    3.000000
#
# ...

# %%
df.groupby("sim_type")['stand_by_time'].max()
# Out:
# sim_type
# 0     914
# 1    1093
# 2     840
# 3     600
# 4     410
# Name: stand_by_time, dtype: int64

# %%
df.groupby('sim_type').agg({'stand_by_time': ['min', 'max'], 'aperture': 'mean'})
# Out:
#          stand_by_time        aperture
#                    min   max      mean
# sim_type
# 0                  160   914  7.830769
# 1                  182  1093  7.083333
# 2                  354   840  4.750000
# 3                  180   600  8.320000
# 4                  360   410  7.333333

# %%
df.groupby(['sim_type','aperture']).mean()
# Out:
#                     gpu_rank      weight  stand_by_time  processor_frequency  \
# sim_type aperture
# 0        1         49.500000  150.062500     428.875000             1.400000
#          3         41.000000  148.000000     566.000000             1.000000
#          4         41.000000  172.000000     350.000000             1.200000
#          5          3.000000  154.500000     321.000000             2.300000
#          7         34.000000  170.666667     346.000000             1.766667
#          8         33.625000  158.508333     439.125000             1.566667
#          9         49.000000  141.500000     337.000000             1.350000
#          10        33.368421  152.315789     339.684211             1.557895
#          11        43.000000  133.000000     198.000000             1.200000
#          12        55.000000  155.000000     250.000000             1.300000
#          13        31.500000  163.500000     680.500000             1.600000
# ...

# %% [markdown]
# ##### Pivot Table
#
# A pivot table is a data summarization tool that is used in the context of data processing. Pivot tables are used to summarize, sort, reorganize, group, count, total or average data stored in a database. It allows its users to transform columns into rows and rows into columns. It allows grouping by any data field. Pivot tables are the perfect solution when you need to summarize and analyze large amounts of data.

# %%
pd.pivot_table(df, values="price",
    index="sim_type",
    columns='is_liked',
    aggfunc='mean')
# Out:
# is_liked         0             1
# sim_type
# 0         11313.00  14722.016667
# 1         19872.00  10700.500000
# 2         15421.50           NaN
# 3         32440.75  34447.952381
# 4              NaN  30615.333333

# %% [markdown]
# ##### Crosstab
#
# The pandas crosstab function builds a cross-tabulation table that can show the frequency with which certain groups of data appear.

# %%
pd.crosstab(df.sim_type,df.is_liked,values=df.price, aggfunc='mean')
# Out:
# is_liked         0             1
# sim_type
# 0         11313.00  14722.016667
# 1         19872.00  10700.500000
# 2         15421.50           NaN
# 3         32440.75  34447.952381
# 4              NaN  30615.333333

# %% [markdown]
# ##### Concatenate, Merge, Join
#
# These functions are used to combine multiple dataframes. It is important to understand their usage.
#
# Here's a quick summary:
# - **merge()** for combining data on common columns or indices
# - **.join()** for combining data on a key column or an index
# - **concat()** for combining DataFrames across rows or columns
#
#
# # What is a Join Operation?
# Join is a common database operation which combines data from two files, data sources, tables, views, or query outputs based on a given condition.
# ![Join Operations](https://www1.udel.edu/evelyn/SQL-Class2/joins.jpg)
#
#
#
# ## Merge
# Concatenation is a process of joining of the object along an axis, with set logic applied to other axes, if any (because a series doesn’t have any other axes). These are the main parameters involved in pandas concatenation- object, axis, handling of other axes, and keys.
#
#
# ## Join
# Concatenation is a process of joining of the object along an axis, with set logic applied to other axes, if any (because a series doesn’t have any other axes). These are the main parameters involved in pandas concatenation- object, axis, handling of other axes, and keys.
#
#
# ## Concatenate
# Concatenation is a process of joining of the object along an axis, with set logic applied to other axes, if any (because a series doesn’t have any other axes). These are the main parameters involved in pandas concatenation- object, axis, handling of other axes, and keys.

# %%
city_data = pd.DataFrame([{"City":"Mysore", "state":"Karnataka"},{"City":"Hyderabad", "state":"Telangana"},{"City":"Bangalore","state":"Karnataka"},{"City":"Vizag", "state":"Andhra"}])

# %%
city_data
# Out:
#         City      state
# 0     Mysore  Karnataka
# 1  Hyderabad  Telangana
# 2  Bangalore  Karnataka
# 3      Vizag     Andhra

# %%
newcitydf = pd.DataFrame([{"City":"Chandigarh","state":"Punjab"},{"City":"Tirupati","state":"Andhra"}])
newcitydf
# Out:
#          City   state
# 0  Chandigarh  Punjab
# 1    Tirupati  Andhra

# %%
city_data = pd.concat(   [city_data, newcitydf]    )

# %%
city_data
# Out:
#          City      state
# 0      Mysore  Karnataka
# 1   Hyderabad  Telangana
# 2   Bangalore  Karnataka
# 3       Vizag     Andhra
# 0  Chandigarh     Punjab
# 0  Chandigarh     Punjab
# 1    Tirupati     Andhra

# %%
pd.merge(newcitydf, city_data, how='left', on='City')
# Out:
#          City state_x state_y
# 0  Chandigarh  Punjab  Punjab
# 1  Chandigarh  Punjab  Punjab
# 2    Tirupati  Andhra  Andhra

# %%
pd.merge(newcitydf, city_data, how='right', on='City')
# Out:
#          City state_x    state_y
# 0  Chandigarh  Punjab     Punjab
# 1  Chandigarh  Punjab     Punjab
# 2    Tirupati  Andhra     Andhra
# 3      Mysore     NaN  Karnataka
# 4   Hyderabad     NaN  Telangana
# 5   Bangalore     NaN  Karnataka
# 6       Vizag     NaN     Andhra

# %% [markdown]
# ##### Real Data: Duplicates and Missing Values
#
# Let us consider an online survey for a product. Many a times, people do not share all the information related to them. Few people share their experience, but not how long they are using the product; few people share how long they are using the product, their experience but not their contact information. Thus, in some or the other way a part of data is always missing, and this is very common in real time.
#
#
#
# ## Empty Data Datatypes
# - None
# - null
# - np.nan
# - NaN
#
# ### References:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html \
# https://www.kaggle.com/dansbecker/handling-missing-values \
# https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/

# %%
import numpy as np
dict1 = {'AvgMarks':[100, 90, np.nan, 95], 
        'Second Score': [30, 45, 56, np.nan], 
        'Third Score':[np.nan, 40, 80, 98]} 
  
df = pd.DataFrame(dict1) 
df
# Out:
#    AvgMarks  Second Score  Third Score
# 0     100.0          30.0          NaN
# 1      90.0          45.0         40.0
# 2       NaN          56.0         80.0
# 3      95.0           NaN         98.0

# %%
df['AvgMarks'].sum()
# Out:
# 285.0

# %%
df['AvgMarks'].mean()
# Out:
# 95.0

# %%
100*(df.isnull().sum()/df.shape[0])
# Out:
# AvgMarks        1
# Second Score    1
# Third Score     1
# dtype: int64

# %% [markdown]
# ##### Treating Missing Values
# There are two ways to treat missing values:
#
# - Delete: Delete the missing values
# - Impute:
#   - Imputing by a simple statistic: Replace the missing values by another value, commonly the mean, median, mode etc.
#   - Predictive techniques: Use statistical models such as k-NN, SVM etc. to predict and impute missing values
#
# ### Note:
# When imputing the missing values with the descriptive statistics, we are making an assumption as we don't know the true values which are missing. Hence, missing values imputation should be performed only when we are confident about our assumptions. On the other hand, removing missing data is often considered safer as we aren't making any assumptions and are not adding any data to the dataset
#
# ### General rules for missing value handling
# - If less than 5% of the data in a column is missing, we can safely remove the rows which have the missing values as we'll still be left with atleast 95% of rows
# - If atleast 40% of the data goes missing in a column, it's better we remove the entire column as the data we know is less than the data we don't know
# - For rest of the cases. depending on how the data is distributed, we can impute the values
#
# Note: When handling missing values, we have to handle each column separately

# %%
# percentage of missing values
(df.isnull().sum() / len(df)) * 100
# Out:
# AvgMarks        25.0
# Second Score    25.0
# Third Score     25.0
# dtype: float64

# %%
dict1 = {'First Score':[100, 90, np.nan, 95], 
        'Second Score': [30, 45, 56, np.nan], 
        'Third Score':[np.nan, 40, 80, 98]} 
  
df1 = pd.DataFrame(dict1) 
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0a0c7068c28b> in <module>
# ----> 1 dict1 = {'First Score':[100, 90, np.nan, 95],
#       2         'Second Score': [30, 45, 56, np.nan],
#       3         'Third Score':[np.nan, 40, 80, 98]}
#       4
#       5 df1 = pd.DataFrame(dict1)
#
# NameError: name 'np' is not defined

# %%
df1.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# ##### Apply and Lambda Functions

# %%
df1['First Score'].apply(lambda x:"centum" if x==100 else "Not Centum")
# Out:
# 0        centum
# 1    Not Centum
# 2    Not Centum
# 3    Not Centum
# Name: First Score, dtype: object

# %%
def centum(avg):
    if avg==100:
        return("Centum")
    else:
        return("NOT Centum")

# %%
df["New Column"]=df["AvgMarks"].apply(centum)

# %%
df
# Out:
#    AvgMarks  Second Score  Third Score  New Column
# 0     100.0     30.000000    72.666667      Centum
# 1      90.0     45.000000    40.000000  NOT Centum
# 2      95.0     56.000000    80.000000  NOT Centum
# 3      95.0     43.666667    98.000000  NOT Centum

# %%
df["New Column1"]=df["AvgMarks"].apply(lambda x:"Centum" if x==100 else "NOT Centum")

# %%
df
# Out:
#    AvgMarks  Second Score  Third Score  New Column New Column1
# 0     100.0     30.000000    72.666667      Centum      Centum
# 1      90.0     45.000000    40.000000  NOT Centum  NOT Centum
# 2      95.0     56.000000    80.000000  NOT Centum  NOT Centum
# 3      95.0     43.666667    98.000000  NOT Centum  NOT Centum

# %% [markdown]
# ##### Apply Map

# %%
df1.applymap(lambda x: len(str(x)))
# Out:
#    First Score  Second Score  Third Score
# 0            5             4            3
# 1            4             4            4
# 2            3             4            4
# 3            4             3            4

# %%
import pandas as pd

df_titanic = pd.read_csv("./data/Titanic.csv")

df_titanic.head(20)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# ## String Methods
#
# We can use the usual string methods to manipulate data inside of a dataframe. To invoke a string method use the .str attribute of a series. Since the only column that is stored as a string is the Name column we will work with that.

# %%
#Using the lower() method

df_titanic["Name"].str.lower().head()
# Out:
# 0                                kelly, mr. james
# 1                wilkes, mrs. james (ellen needs)
# 2                       myles, mr. thomas francis
# 3                                wirz, mr. albert
# 4    hirvonen, mrs. alexander (helga e lindqvist)
# Name: Name, dtype: object

# %% [markdown]
# The above bit of code returns the Name column as a str with all lowercase letters. Another useful string method is the contains() method, which returns a boolean if the given string contain the input string.

# %%
#using contains() method to check for title Mr.
df_titanic["Name"].str.contains("Mr\.").head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Name, dtype: bool

# %% [markdown]
# Note that we need the escape character "\" to look for the ".".  We can easily the results of the returned series in a new column as follows.

# %%
#Creating new column
df_titanic["Bool_Mr"] = df_titanic["Name"].str.contains("Mr\.")

df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Bool_Mr
# 0  34.5      0      0   330911   7.8292   NaN        Q     True
# 1  47.0      1      0   363272   7.0000   NaN        S    False
# 2  62.0      0      0   240276   9.6875   NaN        Q     True
# 3  27.0      0      0   315154   8.6625   NaN        S     True
# 4  22.0      1      1  3101298  12.2875   NaN        S    False

# %% [markdown]
# Now we have a new boolean column and we can easily figure out, for example, the total number of "Mr."s as follows

# %%
#Computing the proportion of Mr.s
df_titanic["Bool_Mr"].mean()
# Out:
# 0.5741626794258373

# %% [markdown]
# We can also use these string methods on the column names. Let's say I want to replace all the underscores (there is only one) with blank spaces.  I can do that with the replace method. Recall that I access the column names through the columns attribute of any dataframe.

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Bool_Mr'],
#       dtype='object')

# %%
#Replace the underscore
df_titanic.columns = df_titanic.columns.str.replace(",", "")

df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Bool_Mr
# 0  34.5      0      0   330911   7.8292   NaN        Q     True
# 1  47.0      1      0   363272   7.0000   NaN        S    False
# 2  62.0      0      0   240276   9.6875   NaN        Q     True
# 3  27.0      0      0   315154   8.6625   NaN        S     True
# 4  22.0      1      1  3101298  12.2875   NaN        S    False

# %% [markdown]
# ## Map
#
# The map method lets us map values in a column to other values. Let's use map to create a binary column that is 1 for females and 0 for males. We give the mapping that we want by providing the appropriate dictionary

# %%
#Using map
df_titanic["Sex"].map({"male":1, "female":0}).head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Sex, dtype: int64

# %% [markdown]
# The result is a series, which we can again store as a column

# %%
#Use map to create new column
df_titanic["Binary_Male"] = df_titanic.Sex.map({"male":1, "female":0})

df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Binary_Male
# 0  34.5      0      0   330911   7.8292   NaN        Q            1
# 1  47.0      1      0   363272   7.0000   NaN        S            0
# 2  62.0      0      0   240276   9.6875   NaN        Q            1
# 3  27.0      0      0   315154   8.6625   NaN        S            1
# 4  22.0      1      1  3101298  12.2875   NaN        S            0

# %% [markdown]
# Let's compute the fraction of male passengers.

# %%
#Compute fraction of male passengers
df_titanic.Binary_Male.mean()
# Out:
# 0.6363636363636364

# %% [markdown]
# ## Apply
#
# The apply method applies built-in or custom functions to each row or column of a dataframe. Let's use the apply method to compute the average age and fair. We will need the mean function from numpy to do so.

# %%
#Using apply - axis =0
import numpy as np

df_titanic[["Age", "Fare"]].apply(np.mean,axis=0)
# Out:
# Age     30.272590
# Fare    35.627188
# dtype: float64

# %% [markdown]
# When using apply, you first specify the function you want applied and then you specify whether you want the function applied to each row (axis = 1) or each column (axis = 0).  The result is a series where the index are the column names.

# %%
#Using apply - axis = 1
df_titanic[["Age", "Fare"]].apply(np.mean,axis=1).head()
# Out:
# 0    21.16460
# 1    27.00000
# 2    35.84375
# 3    17.83125
# 4    17.14375
# dtype: float64

# %% [markdown]
# Now let's say we also want to look at rounded  versions of the columns corresponding to the rounded age and fare. We can use numpy's round function and the apply method to accomplish this.

# %%
#Using apply with the round function
rounded_cols = df_titanic[["Age", "Fare"]].apply(np.round).head()
rounded_cols.head()
# Out:
#     Age  Fare
# 0  34.0   8.0
# 1  47.0   7.0
# 2  62.0  10.0
# 3  27.0   9.0
# 4  22.0  12.0
